# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,joblib
import re 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:\\Users\\Pareta\\Desktop\\laptop_price_prediction\\laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
sns.distplot(df['Price'])
plt.show()

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='Company',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='TypeName',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.distplot(df['Inches'])
plt.show()

# %%
sns.scatterplot(x='Inches',y='Price',data=df)
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['TouchScreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0

# %%
df['TouchScreen'].value_counts()
# Out:
# TouchScreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
df['TouchScreen'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='TouchScreen',y='Price',data=df)
plt.show()

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df['IPS'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='IPS',y='Price',data=df)
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#                            X_res Y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
for i in range(len(df['X_res'])):
    X_res=df['X_res'][i]
    df['X_res'][i]=re.sub("[^0-9]","",X_res)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# memory usage: 142.6+ KB

# %%
# X_res and Y_res in integer
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# memory usage: 142.6+ KB

# %%
# PPI=Pixels Per Inches
# PPI=root[((X_res*X_res)+(Y_res*Yres))]/Inches
df['ppi']=(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches'])
df['ppi'].astype('float')
# Out:
# 0       226.983005
# 1       127.677940
# 2       141.211998
# 3       220.534624
# 4       226.983005
#            ...
# 1298    157.350512
# 1299    276.053530
# 1300    111.935204
# 1301    100.454670
# 1302    100.454670
# Name: ppi, Length: 1303, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS  X_res  Y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# 2   30636.0000            0    0   1920   1080  141.211998
# 3  135195.3360            0    1   2880   1800  220.534624
# 4   96095.8080            0    1   2560   1600  226.983005

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))   #" ".join is used to convert it into string.
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand']=df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu Brand
# 0  226.983005  Intel Core i5  Intel Core i5
# 1  127.677940  Intel Core i5  Intel Core i5
# 2  141.211998  Intel Core i5  Intel Core i5
# 3  220.534624  Intel Core i7  Intel Core i7
# 4  226.983005  Intel Core i5  Intel Core i5

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x='Cpu Brand',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         ppi      Cpu Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x='Ram',y='Price',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
import pandas as pd

# Assuming the DataFrame is already loaded and named as 'df'

# Function to extract storage sizes from the memory specification
def extract_storage_sizes(memory):
    ssd = 0
    hdd = 0
    hybrid = 0
    flash_storage = 0
    
    # Splitting the memory specification by '+' to handle multiple storage types
    components = memory.split('+')
    for component in components:
        component = component.strip()  # Remove leading/trailing spaces
        if 'SSD' in component:
            # Extracting SSD size
            ssd += int(''.join(filter(str.isdigit, component)))
        elif 'HDD' in component:
            # Extracting HDD size
            hdd += int(''.join(filter(str.isdigit, component)))
        elif 'Hybrid' in component:
            # Extracting Hybrid size
            hybrid += int(''.join(filter(str.isdigit, component)))
        elif 'Flash Storage' in component:
            # Extracting Flash Storage size
            flash_storage += int(''.join(filter(str.isdigit, component)))
    
    return pd.Series([ssd, hdd, hybrid, flash_storage])

# Apply the function and create new columns
df[['SSD', 'HDD', 'Hybrid', 'Flash_Storage']] = df['Memory'].apply(extract_storage_sizes)

# %%
df.sample(10)
# Out:
#       Company            TypeName  Ram              Memory  \
# 430   Samsung             Netbook    4  16GB Flash Storage
# 433    Lenovo         Workstation   16           512GB SSD
# 103        HP           Ultrabook    8           256GB SSD
# 1139       HP           Ultrabook    8           256GB SSD
# 895   Toshiba            Notebook    8           256GB SSD
# 1249     Dell  2 in 1 Convertible    8           256GB SSD
# 567   Fujitsu            Notebook    8             1TB HDD
# 381    Lenovo            Notebook    4           128GB SSD
# 807        HP            Notebook    8             2TB HDD
# 951      Dell           Ultrabook    8           256GB SSD
#
#                          Gpu       OpSys  Weight        Price  TouchScreen  \
# 430    Intel HD Graphics 400   Chrome OS    1.15   14332.3200            0
# 433     Nvidia GeForce 940MX  Windows 10    2.30  130269.6000            0
# 103     Nvidia GeForce MX150  Windows 10    1.38   59620.3200            0
# 1139   Intel HD Graphics 520   Windows 7    1.88  115709.2416            0
# 895    Intel HD Graphics 620  Windows 10    1.05   78588.0000            0
# 1249   Intel HD Graphics 615  Windows 10    1.24   96596.6400            1
# 567    Intel HD Graphics 620  Windows 10    2.20   39373.9200            0
# 381    Intel HD Graphics 520       No OS    1.85   21498.4800            0
# 807   AMD Radeon R7 Graphics  Windows 10    2.04   33513.1200            0
# 951    Intel HD Graphics 620  Windows 10    1.36   94572.0000            0
#
#       IPS          ppi              Cpu Brand  SSD  HDD  Hybrid  Flash_Storage
# 430     0   135.094211  Other Intel Processor    0    0       0             16
# 433     1  2813.665348          Intel Core i7  512    0       0              0
# 103     1   165.632118          Intel Core i7  256    0       0              0
# 1139    0   141.211998          Intel Core i7  256    0       0              0
# 895     0   165.632118          Intel Core i5  256    0       0              0
# 1249    0   276.053530          Intel Core i5  256    0       0              0
# 567     0   100.454670          Intel Core i5    0    1       0              0
# 381     0   141.211998          Intel Core i3  128    0       0              0
# 807     0   100.454670          AMD Processor    0    2       0              0
# 951     0   157.350512          Intel Core i7  256    0       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS         ppi      Cpu Brand  SSD  HDD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  128    0       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5  256    0       0
# 3  135195.3360            0    1  220.534624  Intel Core i7  512    0       0
# 4   96095.8080            0    1  226.983005  Intel Core i5  256    0       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)     # Drop because price not very much depend on Hybrid or Flash_Storage.

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS         ppi      Cpu Brand  SSD  HDD
# 0   71378.6832            0    1  226.983005  Intel Core i5  128    0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5  256    0
# 3  135195.3360            0    1  220.534624  Intel Core i7  512    0
# 4   96095.8080            0    1  226.983005  Intel Core i5  256    0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu Brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS         ppi      Cpu Brand  SSD  HDD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  128    0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5  256    0
# 3  135195.3360            0    1  220.534624  Intel Core i7  512    0
# 4   96095.8080            0    1  226.983005  Intel Core i5  256    0
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df=df[df['Gpu Brand']!='ARM']

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x='Gpu Brand',y='Price',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu Brand  SSD  HDD Gpu Brand
# 0  226.983005  Intel Core i5  128    0     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5  256    0     Intel
# 3  220.534624  Intel Core i7  512    0       AMD
# 4  226.983005  Intel Core i5  256    0     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x='OpSys',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
def cat_os(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'No OS/Linux/Android/Chrome OS'

# %%
df['OS']=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu Brand  SSD  HDD Gpu Brand  \
# 0  226.983005  Intel Core i5  128    0     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5  256    0     Intel
# 3  220.534624  Intel Core i7  512    0       AMD
# 4  226.983005  Intel Core i5  256    0     Intel
#
#                               OS
# 0                            Mac
# 1                            Mac
# 2  No OS/Linux/Android/Chrome OS
# 3                            Mac
# 4                            Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  TouchScreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  SSD  HDD Gpu Brand                             OS
# 0  Intel Core i5  128    0     Intel                            Mac
# 1  Intel Core i5    0    0     Intel                            Mac
# 2  Intel Core i5  256    0     Intel  No OS/Linux/Android/Chrome OS
# 3  Intel Core i7  512    0       AMD                            Mac
# 4  Intel Core i5  256    0     Intel                            Mac

# %%
sns.barplot(x='OS',y='Price',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x='Weight',y='Price',data=df)
plt.show()

# %%
sns.distplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        8
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
Company_brand=list(df['Company'].value_counts().head(8).index)
Company_brand
# Out:
# ['Dell', 'Lenovo', 'HP', 'Asus', 'Acer', 'MSI', 'Toshiba', 'Apple']

# %%
df2=df[df['Company'].isin(Company_brand)]
df2.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  TouchScreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  SSD  HDD Gpu Brand                             OS
# 0  Intel Core i5  128    0     Intel                            Mac
# 1  Intel Core i5    0    0     Intel                            Mac
# 2  Intel Core i5  256    0     Intel  No OS/Linux/Android/Chrome OS
# 3  Intel Core i7  512    0       AMD                            Mac
# 4  Intel Core i5  256    0     Intel                            Mac

# %%
df2['Company'].value_counts()
# Out:
# Company
# Lenovo     297
# Dell       297
# HP         274
# Asus       158
# Acer       103
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
dt={'Lenovo': 1,'Dell': 2,'HP': 3,
 'Asus': 4,
 'Acer': 5,
 'MSI': 6,
 'Toshiba': 7,
 'Apple': 8}

# %%
df['Company']=df['Company'].map(dt)
df
# Out:
#       Company            TypeName  Ram  Weight        Price  TouchScreen  IPS  \
# 0         8.0           Ultrabook    8    1.37   71378.6832            0    1
# 1         8.0           Ultrabook    8    1.34   47895.5232            0    0
# 2         3.0            Notebook    8    1.86   30636.0000            0    0
# 3         8.0           Ultrabook   16    1.83  135195.3360            0    1
# 4         8.0           Ultrabook    8    1.37   96095.8080            0    1
# ...       ...                 ...  ...     ...          ...          ...  ...
# 1298      1.0  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299      1.0  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300      1.0            Notebook    2    1.50   12201.1200            0    0
# 1301      3.0            Notebook    6    2.19   40705.9200            0    0
# 1302      4.0            Notebook    4    2.20   19660.3200            0    0
#
#              ppi              Cpu Brand  SSD  HDD Gpu Brand  \
# 0     226.983005          Intel Core i5  128    0     Intel
# 1     127.677940          Intel Core i5    0    0     Intel
# 2     141.211998          Intel Core i5  256    0     Intel
# 3     220.534624          Intel Core i7  512    0       AMD
# 4     226.983005          Intel Core i5  256    0     Intel
# ...          ...                    ...  ...  ...       ...
# 1298  157.350512          Intel Core i7  128    0     Intel
# 1299  276.053530          Intel Core i7  512    0     Intel
# 1300  111.935204  Other Intel Processor    0    0     Intel
# 1301  100.454670          Intel Core i7    0    1       AMD
# 1302  100.454670  Other Intel Processor    0  500     Intel
#
#                                  OS
# 0                               Mac
# 1                               Mac
# 2     No OS/Linux/Android/Chrome OS
# 3                               Mac
# 4                               Mac
# ...                             ...
# 1298                        Windows
# 1299                        Windows
# 1300                        Windows
# 1301                        Windows
# 1302                        Windows
#
# [1302 rows x 13 columns]

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    120
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
typename=list(df['TypeName'].value_counts().head(4).index)
typename
# Out:
# ['Notebook', 'Gaming', 'Ultrabook', '2 in 1 Convertible']

# %%
df2=df[df['TypeName'].isin(typename)]
df2.head()
# Out:
#    Company   TypeName  Ram  Weight        Price  TouchScreen  IPS         ppi  \
# 0      8.0  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1      8.0  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      3.0   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3      8.0  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4      8.0  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  SSD  HDD Gpu Brand                             OS
# 0  Intel Core i5  128    0     Intel                            Mac
# 1  Intel Core i5    0    0     Intel                            Mac
# 2  Intel Core i5  256    0     Intel  No OS/Linux/Android/Chrome OS
# 3  Intel Core i7  512    0       AMD                            Mac
# 4  Intel Core i5  256    0     Intel                            Mac

# %%
dt1={'Notebook':1,'Gaming':2,'Ultrabook':3,'2 in 1 Convertible':4}

# %%
df['TypeName']=df['TypeName'].map(dt1)
df
# Out:
#       Company  TypeName  Ram  Weight        Price  TouchScreen  IPS  \
# 0         8.0       3.0    8    1.37   71378.6832            0    1
# 1         8.0       3.0    8    1.34   47895.5232            0    0
# 2         3.0       1.0    8    1.86   30636.0000            0    0
# 3         8.0       3.0   16    1.83  135195.3360            0    1
# 4         8.0       3.0    8    1.37   96095.8080            0    1
# ...       ...       ...  ...     ...          ...          ...  ...
# 1298      1.0       4.0    4    1.80   33992.6400            1    1
# 1299      1.0       4.0   16    1.30   79866.7200            1    1
# 1300      1.0       1.0    2    1.50   12201.1200            0    0
# 1301      3.0       1.0    6    2.19   40705.9200            0    0
# 1302      4.0       1.0    4    2.20   19660.3200            0    0
#
#              ppi              Cpu Brand  SSD  HDD Gpu Brand  \
# 0     226.983005          Intel Core i5  128    0     Intel
# 1     127.677940          Intel Core i5    0    0     Intel
# 2     141.211998          Intel Core i5  256    0     Intel
# 3     220.534624          Intel Core i7  512    0       AMD
# 4     226.983005          Intel Core i5  256    0     Intel
# ...          ...                    ...  ...  ...       ...
# 1298  157.350512          Intel Core i7  128    0     Intel
# 1299  276.053530          Intel Core i7  512    0     Intel
# 1300  111.935204  Other Intel Processor    0    0     Intel
# 1301  100.454670          Intel Core i7    0    1       AMD
# 1302  100.454670  Other Intel Processor    0  500     Intel
#
#                                  OS
# 0                               Mac
# 1                               Mac
# 2     No OS/Linux/Android/Chrome OS
# 3                               Mac
# 4                               Mac
# ...                             ...
# 1298                        Windows
# 1299                        Windows
# 1300                        Windows
# 1301                        Windows
# 1302                        Windows
#
# [1302 rows x 13 columns]

# %%
df['Cpu Brand'].value_counts()
# Out:
# Cpu Brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             62
# Name: count, dtype: int64

# %%
dt2={'Intel Core i7':1,'Intel Core i5':2,'Other Intel Processor':4,'Intel Core i3':3,'AMD Processor ':5}

# %%
df['Cpu Brand']=df['Cpu Brand'].map(dt2)
df
# Out:
#       Company  TypeName  Ram  Weight        Price  TouchScreen  IPS  \
# 0         8.0       3.0    8    1.37   71378.6832            0    1
# 1         8.0       3.0    8    1.34   47895.5232            0    0
# 2         3.0       1.0    8    1.86   30636.0000            0    0
# 3         8.0       3.0   16    1.83  135195.3360            0    1
# 4         8.0       3.0    8    1.37   96095.8080            0    1
# ...       ...       ...  ...     ...          ...          ...  ...
# 1298      1.0       4.0    4    1.80   33992.6400            1    1
# 1299      1.0       4.0   16    1.30   79866.7200            1    1
# 1300      1.0       1.0    2    1.50   12201.1200            0    0
# 1301      3.0       1.0    6    2.19   40705.9200            0    0
# 1302      4.0       1.0    4    2.20   19660.3200            0    0
#
#              ppi  Cpu Brand  SSD  HDD Gpu Brand                             OS
# 0     226.983005        2.0  128    0     Intel                            Mac
# 1     127.677940        2.0    0    0     Intel                            Mac
# 2     141.211998        2.0  256    0     Intel  No OS/Linux/Android/Chrome OS
# 3     220.534624        1.0  512    0       AMD                            Mac
# 4     226.983005        2.0  256    0     Intel                            Mac
# ...          ...        ...  ...  ...       ...                            ...
# 1298  157.350512        1.0  128    0     Intel                        Windows
# 1299  276.053530        1.0  512    0     Intel                        Windows
# 1300  111.935204        4.0    0    0     Intel                        Windows
# 1301  100.454670        1.0    0    1       AMD                        Windows
# 1302  100.454670        4.0    0  500     Intel                        Windows
#
# [1302 rows x 13 columns]

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
dt3={'Intel':1,'Nvidia':2,'AMD':3}

# %%
df['Gpu Brand']=df['Gpu Brand'].map(dt3)
df
# Out:
#       Company  TypeName  Ram  Weight        Price  TouchScreen  IPS  \
# 0         8.0       3.0    8    1.37   71378.6832            0    1
# 1         8.0       3.0    8    1.34   47895.5232            0    0
# 2         3.0       1.0    8    1.86   30636.0000            0    0
# 3         8.0       3.0   16    1.83  135195.3360            0    1
# 4         8.0       3.0    8    1.37   96095.8080            0    1
# ...       ...       ...  ...     ...          ...          ...  ...
# 1298      1.0       4.0    4    1.80   33992.6400            1    1
# 1299      1.0       4.0   16    1.30   79866.7200            1    1
# 1300      1.0       1.0    2    1.50   12201.1200            0    0
# 1301      3.0       1.0    6    2.19   40705.9200            0    0
# 1302      4.0       1.0    4    2.20   19660.3200            0    0
#
#              ppi  Cpu Brand  SSD  HDD  Gpu Brand  \
# 0     226.983005        2.0  128    0          1
# 1     127.677940        2.0    0    0          1
# 2     141.211998        2.0  256    0          1
# 3     220.534624        1.0  512    0          3
# 4     226.983005        2.0  256    0          1
# ...          ...        ...  ...  ...        ...
# 1298  157.350512        1.0  128    0          1
# 1299  276.053530        1.0  512    0          1
# 1300  111.935204        4.0    0    0          1
# 1301  100.454670        1.0    0    1          3
# 1302  100.454670        4.0    0  500          1
#
#                                  OS
# 0                               Mac
# 1                               Mac
# 2     No OS/Linux/Android/Chrome OS
# 3                               Mac
# 4                               Mac
# ...                             ...
# 1298                        Windows
# 1299                        Windows
# 1300                        Windows
# 1301                        Windows
# 1302                        Windows
#
# [1302 rows x 13 columns]

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows                          1125
# No OS/Linux/Android/Chrome OS     156
# Mac                                21
# Name: count, dtype: int64

# %%
dt4={'Windows':1,'Mac':2,'No OS/Linux/Android/Chrome OS':3}

# %%
df['OS']=df['OS'].map(dt4)
df
# Out:
#       Company  TypeName  Ram  Weight        Price  TouchScreen  IPS  \
# 0         8.0       3.0    8    1.37   71378.6832            0    1
# 1         8.0       3.0    8    1.34   47895.5232            0    0
# 2         3.0       1.0    8    1.86   30636.0000            0    0
# 3         8.0       3.0   16    1.83  135195.3360            0    1
# 4         8.0       3.0    8    1.37   96095.8080            0    1
# ...       ...       ...  ...     ...          ...          ...  ...
# 1298      1.0       4.0    4    1.80   33992.6400            1    1
# 1299      1.0       4.0   16    1.30   79866.7200            1    1
# 1300      1.0       1.0    2    1.50   12201.1200            0    0
# 1301      3.0       1.0    6    2.19   40705.9200            0    0
# 1302      4.0       1.0    4    2.20   19660.3200            0    0
#
#              ppi  Cpu Brand  SSD  HDD  Gpu Brand  OS
# 0     226.983005        2.0  128    0          1   2
# 1     127.677940        2.0    0    0          1   2
# 2     141.211998        2.0  256    0          1   3
# 3     220.534624        1.0  512    0          3   2
# 4     226.983005        2.0  256    0          1   2
# ...          ...        ...  ...  ...        ...  ..
# 1298  157.350512        1.0  128    0          1   1
# 1299  276.053530        1.0  512    0          1   1
# 1300  111.935204        4.0    0    0          1   1
# 1301  100.454670        1.0    0    1          3   1
# 1302  100.454670        4.0    0  500          1   1
#
# [1302 rows x 13 columns]

# %%
x=df.drop(columns=['Price'])
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15)

# %%
x_train.head()
# Out:
#       Company  TypeName  Ram  Weight  TouchScreen  IPS         ppi  Cpu Brand  \
# 1164      3.0       1.0    4    2.10            0    0  100.454670        2.0
# 1029      3.0       1.0    8    2.63            0    0  127.335675        2.0
# 673       1.0       1.0    4    2.20            0    0  100.454670        NaN
# 813       2.0       1.0    8    1.98            0    0  141.211998        1.0
# 878       2.0       1.0    4    2.18            0    0  141.211998        2.0
#
#       SSD  HDD  Gpu Brand  OS
# 1164    0  500          1   3
# 1029  256    0          2   1
# 673   128    0          3   1
# 813     0    1          2   1
# 878   128    1          2   1

# %%
y_train.head()
# Out:
# 1164    25414.0272
# 1029    57542.4000
# 673     18594.7200
# 813     51202.0800
# 878     48618.0000
# Name: Price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.svm import SVC,SVR
from sklearn.impute import SimpleImputer

# %%
df.isnull().sum()
# Out:
# Company        50
# TypeName       54
# Ram             0
# Weight          0
# Price           0
# TouchScreen     0
# IPS             0
# ppi             0
# Cpu Brand      62
# SSD             0
# HDD             0
# Gpu Brand       0
# OS              0
# dtype: int64

# %%
df= df.dropna()

# %%
df.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# Price          0
# TouchScreen    0
# IPS            0
# ppi            0
# Cpu Brand      0
# SSD            0
# HDD            0
# Gpu Brand      0
# OS             0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')
x_train = imputer.fit_transform(x_train)

# Impute missing values in the testing data
x_test = imputer.transform(x_test)

# Initialize the models
lnr = LinearRegression()
dtr = DecisionTreeRegressor()
rtr = RandomForestRegressor(n_estimators=101, min_samples_split=15, min_samples_leaf=5)

# Fit the models
lnr.fit(x_train, y_train)
print("LinearRegression successfully trained.")

dtr.fit(x_train, y_train)
print("DecisionTreeRegressor successfully trained.")

rtr.fit(x_train, y_train)
print("RandomForestRegressor successfully trained.")

print()

# Score the models
print("LinearRegression training score:", lnr.score(x_train, y_train) * 100)
print("LinearRegression testing score:", lnr.score(x_test, y_test) * 100)
print()
print("DecisionTreeRegressor training score:", dtr.score(x_train, y_train) * 100)
print("DecisionTreeRegressor testing score:", dtr.score(x_test, y_test) * 100)
print()
print("RandomForestRegressor training score:", rtr.score(x_train, y_train) * 100)
print("RandomForestRegressor testing score:", rtr.score(x_test, y_test) * 100)
# Out:
# LinearRegression successfully trained.
# DecisionTreeRegressor successfully trained.
# RandomForestRegressor successfully trained.
#
# LinearRegression training score: 70.3898670868549
# LinearRegression testing score: 60.30965328299476
#
# DecisionTreeRegressor training score: 99.3736413658319
# DecisionTreeRegressor testing score: 49.4051211655664
#
# RandomForestRegressor training score: 86.16298862969087
# RandomForestRegressor testing score: 65.06391767848649

# %%
os.makedirs('models',exist_ok=True)
joblib.dump(rtr,'./models/randomforestregression.lb')
# Out:
# ['./models/randomforestregression.lb']

# %%
df['HDD'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HDD'>
